# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from path_extract.clmt_pilot.study import plot_experiment
from path_extract.paths import PIER6, PATH_TO_FIGURES

# %%
# Out:
# 'p1_pier6'

# %%
# Out:
# '250701_CLMT_Pilot_Sprint'

# %%
# for i in range(3):  
charts =  [plot_experiment(PIER6/f"exp_{i}", renderer= "html") for i in range(3)]

# %%
charts[0].show()
# Out:
# alt.Chart(...)

# %%
all_chart = (charts[0] | charts[1] | charts[2]).resolve_scale(y="shared").resolve_legend()
all_chart.show()
# Out:
# alt.HConcatChart(...)

# %%
from pathlib import Path

# %%
path = PATH_TO_FIGURES /PIER6.parent.stem /  PIER6.stem
path.exists()
# Out:
# True

# %%
all_chart.save(path / "compare.html", format="html")
