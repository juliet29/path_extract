# %%
# %load_ext autoreload
# %autoreload 2

# %%
from path_extract.clmt_pilot.study import plot_experiment
from path_extract.project_paths import CLMTPath
# from path_extract.paths import PIER6, PATH_TO_FIGURES

# %%
# for i in range(3): 
project_path = CLMTPath("pier_6") 
charts =  [plot_experiment(project_path, i, renderer= "html") for i in range(3)]

# %%
charts[0].show()
# Out:
# alt.Chart(...)

# %%
all_chart = (charts[0] | charts[1] | charts[2]).resolve_scale(y="shared").resolve_legend()
all_chart.show()
# Out:
# alt.HConcatChart(...)

# %%
path = PATH_TO_FIGURES /PIER6.parent.stem /  PIER6.stem
path.exists()
# Out:
# True

# %%
all_chart.save(project_path.figures_path / "compare.html", format="html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 all_chart.save(project_path.figures_path / "compare.html", format="html")
#
# File ~/_UILCode/gqe-phd/path_extract/.venv/lib/python3.13/site-packages/altair/vegalite/v5/api.py:2289, in TopLevelMixin.save(self, fp, format, override_data_transformer, scale_factor, mode, vegalite_version, vega_version, vegaembed_version, embed_options, json_kwds, engine, inline, **kwargs)
#    2287 if override_data_transformer:
#    2288     with data_transformers.disable_max_rows():
# -> 2289         save(**kwds)
#    2290 else:
#    2291     save(**kwds)
#
# File ~/_UILCode/gqe-phd/path_extract/.venv/lib/python3.13/site-packages/altair/utils/save.py:224, in save(chart, fp, vega_version, vegaembed_version, format, mode, vegalite_version, embed_options, json_kwds, scale_factor, engine, inline, **kwargs)
#     217 else:
#     218     # Temporarily turn off any data transformers so that all data is inlined
#     219     # when calling chart.to_dict. This is relevant for vl-convert which cannot access
#     220     # local json files which could be created by a json data transformer. Furthermore,
#     221     # we don't exit the with statement until this function completed due to the issue
#     222     # described at https://github.com/vega/vl-convert/issues/31
#     223     with data_transformers.enable("default"), data_transformers.disable_max_rows():
# --> 224         perform_save()
#
# File ~/_UILCode/gqe-phd/path_extract/.venv/lib/python3.13/site-packages/altair/utils/save.py:171, in save.<locals>.perform_save()
#     159         kwargs["template"] = "inline"
#     160     mb_html = spec_to_mimebundle(
#     161         spec=spec,
#     162         format=format,
#    (...)    169         **kwargs,
#     170     )
# --> 171     write_file_or_filename(
#     172         fp, mb_html["text/html"], mode="w", encoding=encoding
#     173     )
#     174 elif format == "png":
#     175     mb_png = spec_to_mimebundle(
#     176         spec=spec,
#     177         format=format,
#    (...)    185         **kwargs,
#     186     )
#
# File ~/_UILCode/gqe-phd/path_extract/.venv/lib/python3.13/site-packages/altair/utils/save.py:26, in write_file_or_filename(fp, content, mode, encoding)
#      24 """Write content to fp, whether fp is a string, a pathlib Path or a file-like object."""
#      25 if isinstance(fp, (str, pathlib.Path)):
# ---> 26     with pathlib.Path(fp).open(mode=mode, encoding=encoding) as f:
#      27         f.write(content)
#      28 else:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/path_extract/figures/250701_CLMT_Pilot_Sprint/pier_6/compare.html'
